# %% [markdown]
# ### Milestone 2: Assembling training data, due Wednesday, April 12, 2017
#
# We are aware that you have little time this week, due to the midterm. So this milestone is a bit easier to achieve than the others. The goal for this week is to prepare the data for the modeling phase of the project. You should end up with a typical data setup of training data X and data labels Y.
#
# The exact form of X and Y depends on the ideas you had previously. In general though Y should involve the genre of a movie, and X the features you want to include to predict the genre. Remember from the lecture that more features does not necessarily equal better prediction performance. Use your application knowledge and the insight you gathered from your genre pair analysis and additional EDA to design Y. Do you want to include all genres? Are there genres that you assume to be easier to separate than others? Are there genres that could be grouped together? There is no one right answer here. We are looking for your insight, so be sure to describe your decision process in your notebook.
#
# In preparation for the deep learning part we strongly encourage you to have two sets of training data X, one with the metadata and one with the movie posters. Make sure to have a common key, like the movie ID, to be able to link the two sets together. Also be mindful of the data rate when you obtain the posters. Time your requests and choose which poster resolution you need. In most cases w500 should be sufficient, and probably a lower resolution will be fine.
#
# The notebook to submit this week should at least include:
#
# - Discussion about the imbalanced nature of the data and how you want to address it
# - Description of your data
# - What does your choice of Y look like?
# - Which features do you choose for X and why?
# - How do you sample your data, how many samples, and why?
#
# *Important*: You do not need to upload the data itself to Canvas.

# %%
### Let's import some libraries!
import imdb
# import httplib
import json
import requests
import pandas as pd
import numpy as np
import time
import wget
import matplotlib
# import random
# from sklearn import cluster
# from sklearn import metrics
# from IPython.display import IFrame
# from sklearn.decomposition import PCA
# %matplotlib inline

# %%
## Get the genre codes from IMDB
payload = {'api_key': '9290a6fe9125b32e7bbe5512036be0d0'}
r = requests.get('https://api.themoviedb.org/3/genre/movie/list', params=payload)

genres = pd.DataFrame.from_dict(r.json()["genres"])
genres = genres.set_index("id")
print genres
# Out:
#                   name
# id
# 28              Action
# 12           Adventure
# 16           Animation
# 35              Comedy
# 80               Crime
# 99         Documentary
# 18               Drama
# 10751           Family
# 14             Fantasy
# 36             History
# 27              Horror
# 10402            Music
# 9648           Mystery
# 10749          Romance
# 878    Science Fiction
# 10770         TV Movie
# 53            Thriller
# 10752              War
# 37             Western

# %%
genres = genres["name"].to_dict()
genres
# Out:
# {12: u'Adventure',
#  14: u'Fantasy',
#  16: u'Animation',
#  18: u'Drama',
#  27: u'Horror',
#  28: u'Action',
#  35: u'Comedy',
#  36: u'History',
#  37: u'Western',
#  53: u'Thriller',
#  80: u'Crime',
#  99: u'Documentary',
#  878: u'Science Fiction',
#  9648: u'Mystery',
#  10402: u'Music',
#  10749: u'Romance',
#  10751: u'Family',
#  10752: u'War',
#  10770: u'TV Movie'}

# %%
### Queries to TMDB
    
# intial API parameters
def get_movies(years, page_limit):
    # Outer loop for ever year in range
    for i, year in enumerate(years):
        start = time.time()
        
        # Define initial API parameters for genre and year 
        payload = {'api_key': '9290a6fe9125b32e7bbe5512036be0d0',
                   'sort_by':'popularity.desc',
                   'primary_release_year': year,
                   'page': 1,
                   'language':'en-US',
                   'with_genres':"878|27|10749"}

        r = requests.get('https://api.themoviedb.org/3/discover/movie?', params=payload)
        print 'For ', year, ' there are ', r.json()['total_results'], ' total results across ', r.json()['total_pages'], ' total pages.'
        
        # For first year, create the data frame. Otherwise, add first page to it.
        if i == 0:
            tmdb_movies = pd.io.json.json_normalize(r.json()['results'])
        else:
            tmdb_movies = pd.concat([tmdb_movies, pd.io.json.json_normalize(r.json()['results'])])
        
        # Set max pages to smaller of five or total number
        if r.json()['total_pages'] < page_limit:
            page_max = r.json()['total_pages']
        else:
            page_max = page_limit
        
        # Wait function for polite API querying
        delay = time.time()-start
        if delay < 0.25:
            time.sleep(0.25-delay)
        
        if page_max > 1:
            # Inner loop for every page up to max, startigng with page 2.
            for page in range(2, page_max+1):
                start = time.time()

                payload = {'api_key': '9290a6fe9125b32e7bbe5512036be0d0',
                       'sort_by':'popularity.desc',
                       'primary_release_year': year,
                       'page': page,
                       'language':'en-US',
                       'with_genres':"878|27|10749"}
                
                r = requests.get('https://api.themoviedb.org/3/discover/movie?', params=payload)
                
                tmdb_movies = pd.concat([tmdb_movies, pd.io.json.json_normalize(r.json()['results'])])
                
                delay = time.time()-start
                if delay < 0.25:
                    time.sleep(0.25-delay)

    return tmdb_movies

# %%
movies = get_movies(range(1930,2017), 5)
movies.shape
# Out:
# For  1930  there are  122  total results across  7  total pages.
# For  1931  there are  122  total results across  7  total pages.
# For  1932  there are  139  total results across  7  total pages.
# For  1933  there are  149  total results across  8  total pages.
# For  1934  there are  146  total results across  8  total pages.
# For  1935  there are  166  total results across  9  total pages.
# For  1936  there are  141  total results across  8  total pages.
# For  1937  there are  168  total results across  9  total pages.
# For  1938  there are  138  total results across  7  total pages.
# For  1939  there are  123  total results across  7  total pages.
# For  1940  there are  126  total results across  7  total pages.
# For  1941  there are  144  total results across  8  total pages.
# For  1942  there are  132  total results across  7  total pages.
# For  1943  there are  103  total results across  6  total pages.
# For  1944  there are  104  total results across  6  total pages.
# For  1945  there are  86  total results across  5  total pages.
# For  1946  there are  97  total results across  5  total pages.
# For  1947  there are  94  total results across  5  total pages.
# For  1948  there are  96  total results across  5  total pages.
# For  1949  there are  115  total results across  6  total pages.
# For  1950  there are  89  total results across  5  total pages.
# For  1951  there are  102  total results across  6  total pages.
# For  1952  there are  108  total results across  6  total pages.
# For  1953  there are  125  total results across  7  total pages.
# For  1954  there are  130  total results across  7  total pages.
# For  1955  there are  156  total results across  8  total pages.
# For  1956  there are  144  total results across  8  total pages.
# For  1957  there are  162  total results across  9  total pages.
# For  1958  there are  178  total results across  9  total pages.
# For  1959  there are  151  total results across  8  total pages.
# For  1960  there are  163  total results across  9  total pages.
# For  1961  there are  151  total results across  8  total pages.
# For  1962  there are  160  total results across  8  total pages.
# For  1963  there are  167  total results across  9  total pages.
# For  1964  there are  173  total results across  9  total pages.
# For  1965  there are  202  total results across  11  total pages.
# For  1966  there are  203  total results across  11  total pages.
# For  1967  there are  211  total results across  11  total pages.
# For  1968  there are  231  total results across  12  total pages.
# For  1969  there are  210  total results across  11  total pages.
# For  1970  there are  251  total results across  13  total pages.
# For  1971  there are  266  total results across  14  total pages.
# For  1972  there are  295  total results across  15  total pages.
# For  1973  there are  306  total results across  16  total pages.
# For  1974  there are  294  total results across  15  total pages.
# For  1975  there are  276  total results across  14  total pages.
# For  1976  there are  219  total results across  11  total pages.
# For  1977  there are  253  total results across  13  total pages.
# For  1978  there are  285  total results across  15  total pages.
# For  1979  there are  274  total results across  14  total pages.
# For  1980  there are  341  total results across  18  total pages.
# For  1981  there are  379  total results across  19  total pages.
# For  1982  there are  366  total results across  19  total pages.
# For  1983  there are  356  total results across  18  total pages.
# For  1984  there are  379  total results across  19  total pages.
# For  1985  there are  420  total results across  21  total pages.
# For  1986  there are  428  total results across  22  total pages.
# For  1987  there are  542  total results across  28  total pages.
# For  1988  there are  587  total results across  30  total pages.
# For  1989  there are  566  total results across  29  total pages.
# For  1990  there are  447  total results across  23  total pages.
# For  1991  there are  392  total results across  20  total pages.
# For  1992  there are  372  total results across  19  total pages.
# For  1993  there are  387  total results across  20  total pages.
# For  1994  there are  386  total results across  20  total pages.
# For  1995  there are  461  total results across  24  total pages.
# For  1996  there are  457  total results across  23  total pages.
# For  1997  there are  515  total results across  26  total pages.
# For  1998  there are  520  total results across  26  total pages.
# For  1999  there are  595  total results across  30  total pages.
# For  2000  there are  626  total results across  32  total pages.
# For  2001  there are  684  total results across  35  total pages.
# For  2002  there are  725  total results across  37  total pages.
# For  2003  there are  790  total results across  40  total pages.
# For  2004  there are  860  total results across  43  total pages.
# For  2005  there are  992  total results across  50  total pages.
# For  2006  there are  1159  total results across  58  total pages.
# For  2007  there are  1198  total results across  60  total pages.
# For  2008  there are  1241  total results across  63  total pages.
# For  2009  there are  1374  total results across  69  total pages.
# For  2010  there are  1331  total results across  67  total pages.
# For  2011  there are  1370  total results across  69  total pages.
# For  2012  there are  1436  total results across  72  total pages.
# For  2013  there are  1639  total results across  82  total pages.
# For  2014  there are  1875  total results across  94  total pages.
# For  2015  there are  1970  total results across  99  total pages.
# For  2016  there are  1783  total results across  90  total pages.
# (8662, 14)

# %%
movies.tail(20)
# Out:
#     adult                     backdrop_path            genre_ids      id  \
# 0   False  /2pqYl9JHfzBuZbnwf3m59s4tvDT.jpg    [18, 9648, 10749]  316021
# 1   False  /wZKnVnWOFYUy8U58btL5uG4U372.jpg          [35, 10749]  366514
# 2   False  /6OmrokBxCpkjGmBbYu9WW5sRPha.jpg             [28, 27]  410988
# 3   False  /6nnK9s4z96lh5KnNOcLMjXo9je5.jpg          [18, 10749]  332872
# 4   False  /jw15rAjCHoNJkovcLOu6xb7ecmO.jpg          [35, 10749]  369299
# 5   False  /gLMrWlscDZCEB72PZF4eqaRphEM.jpg  [53, 12, 878, 9648]  401222
# 6   False  /ts2FEI39w6NBOhyqGxPJTidNLuz.jpg         [35, 27, 53]  320413
# 7   False  /eafe4lNtWchWfCRXFnpcpKgLomk.jpg             [53, 27]  364116
# 8   False  /pT9vBaWZqrTC0ExZF9OCsa6p5zK.jpg                 [27]  421601
# 9   False  /iig2oRVfYZdIuY5ygT16pi2G5oz.jpg          [18, 10749]  376166
# 10  False  /xRCRGcmA6odM6LM0i2QdQWqQdrA.jpg             [27, 53]  284564
# 11  False  /uDUxeEQ2YEuxiIoLvYGBqTvp1S8.jpg          [10749, 35]  413417
# 12  False  /7Zq0SKTYIcoIxVOVwv4j2nO5eR3.jpg      [35, 18, 10749]  353571
# 13  False  /y1J1HN3o3zR8vRfKoJQyo3G0rb7.jpg        [28, 27, 878]  384798
# 14  False  /y2iCUN6S3Cue647RI5bZijEga1G.jpg             [28, 27]  395797
# 15  False  /iCyCeKbsh4G3IJPTIL3a4OtFkNL.jpg     [35, 14, 27, 53]  290825
# 16  False  /kIg1sA16YQDblcD7w3qn5MBwsul.jpg             [27, 53]  329440
# 17  False  /3GUg7UEKIR2gyeGL7nPo7dh86Le.jpg          [35, 10749]  409583
# 18  False  /zu1rECEaLcvhI8yVXnBBV4yHf9Q.jpg          [35, 10749]  401917
# 19  False  /2fgz6p16JYI1OnhwFIuVCWCFayG.jpg          [10749, 18]  315880
#
#    original_language              original_title  \
# 0                 en                Frank & Lola
# 1                 fr       Un homme à la hauteur
# 2                 en             The Stakelander
# 3                 es                     Julieta
# 4                 es   ¿Qué culpa tiene el niño?
# 5                 en                     ISRA 88
# 6                 en        The Greasy Strangler
# 7                 en  The Other Side of the Door
# 8                 en               Bornless Ones
# 9                 fr              Mal de pierres
# 10                en                          31
# 11                en            The Matchbreaker
# 12                en                    Tallulah
# 13                en                Kill Command
# 14                en                   The Horde
# 15                en                 Yoga Hosers
# 16                en                  The Forest
# 17                en                       Split
# 18                ja           黒崎くんの言いなりになんてならない
# 19                en           La corrispondenza
#
#                                              overview  popularity  \
# 0   A psychosexual noir love story, set in Las Veg...    2.040600
# 1   Diane is a well-known lawyer, divorced for thr...    2.028859
# 2   When his home of New Eden is destroyed by a re...    2.022309
# 3   The film spans 30 years in Julieta’s life from...    2.021858
# 4   Maru, after becoming pregnant from a drunken o...    2.016717
# 5   When a scientist and a pilot volunteer for a h...    2.012973
# 6   Ronnie runs a Disco walking tour with his son,...    2.003028
# 7   Grieving over the loss of her son, a mother st...    2.000022
# 8   With the help of her friends, Emily moves to a...    1.974140
# 9   An adaptation of Milena Agus' eponymous novel ...    1.941451
# 10  Five people are kidnapped on the days leading ...    1.934257
# 11  When an idealistic romantic gets fired from hi...    1.907639
# 12  Desperate to be rid of her toddler, a dissatis...    1.899577
# 13  Set in a near future, technology-reliant socie...    1.897019
# 14  The film follows John Crenshaw as he accompani...    1.889625
# 15  Two teenage yoga enthusiasts team up with a le...    1.887207
# 16  Set in the Aokigahara Forest, a real-life plac...    1.882735
# 17  As her 30th birthday looms, an over-achieving ...    1.879544
# 18  Yu Akahane (Nana Komatsu) moves to a dormitory...    1.875416
# 19  The relationship between Ed, a married astrono...    1.856391
#
#                          poster_path release_date  \
# 0   /9ZdlnjePpUhxRWz69KjqhIe7H5U.jpg   2016-12-09
# 1   /jJUKI7seMw2S5DKZSBfUPiWKzfU.jpg   2016-05-04
# 2   /fded6orgVzm4EFwZYcNfZJU3Ven.jpg   2016-10-14
# 3   /mwG0YDtmDtEw7371WLIBxmU0xXT.jpg   2016-04-08
# 4   /eWPD4RO7QQjiD8evdnQ0pUmGC33.jpg   2016-05-13
# 5   /rZTJZkSnbEOiXLxdh2Wrn6mdCSJ.jpg   2016-08-08
# 6   /6ZBHD1ZvYuP0uhYuOeTMN4Kgxvl.jpg   2016-10-07
# 7   /hLpbfpkh5MBt86LokeyoReK0yCH.jpg   2016-02-25
# 8   /4V52bmZg4tR96hiuNX3r5h08GvN.jpg   2016-10-06
# 9   /8XAykE6hBjPvg1hbZoPruRSQEW4.jpg   2016-10-19
# 10  /rpxbMjrq4CDPY30dTRbvdQsUcud.jpg   2016-09-15
# 11  /sztdKdVYFNdz6Q6D11Pd8IyCqPK.jpg   2016-10-07
# 12  /zdK8G7LScUHnrnxVKddqBxrR4fN.jpg   2016-01-23
# 13  /nl9e5LIYMOYskBV48AcvEc8FUZi.jpg   2016-05-13
# 14  /cRCWjrtguXuD5nrA3D3Clnk0nYW.jpg   2016-05-06
# 15  /t9K1uUCJsbrFGKYivSH1JBPfvyc.jpg   2016-07-08
# 16  /ox9y8ia8lGqtkmLZD3YghA7sZkU.jpg   2016-01-07
# 17  /8rHD7a48iHdLJqeR4lmdyj2tt9K.jpg   2016-08-02
# 18  /hL8DFImobEETO62ddl5bRnvOl5Z.jpg   2016-02-27
# 19  /ghuK137xSNdtZWxXqG96GUFLeYR.jpg   2016-01-14
#
#                                               title  video  vote_average  \
# 0                                      Frank & Lola  False           6.1
# 1                                       Up for Love  False           5.9
# 2                    Stake Land II: The Stakelander  False           5.3
# 3                                           Julieta  False           6.8
# 4                        Why Blame It on the Child?  False           6.2
# 5                                           ISRA 88  False           4.8
# 6                              The Greasy Strangler  False           5.2
# 7                        The Other Side of the Door  False           5.1
# 8                                     Bornless Ones  False           5.1
# 9                         From the Land of the Moon  False           6.6
# 10                                               31  False           4.6
# 11                                 The Matchbreaker  False           5.9
# 12                                         Tallulah  False           6.8
# 13                                     Kill Command  False           5.1
# 14                                        The Horde  False           4.5
# 15                                      Yoga Hosers  False           4.6
# 16                                       The Forest  False           4.8
# 17                                            Split  False           3.8
# 18  I'm Not Just Going to Do What Kurosaki kun Says  False           7.0
# 19                               The Correspondence  False           6.0
#
#     vote_count
# 0           25
# 1          135
# 2           14
# 3          172
# 4           46
# 5            8
# 6           29
# 7          202
# 8           10
# 9           36
# 10         119
# 11          13
# 12         150
# 13         158
# 14          10
# 15          63
# 16         337
# 17           8
# 18           2
# 19          66

# %%
movies.to_csv("movies_from_1930.csv", encoding = "utf-8")

# %%
movies["original_language"].value_counts()
# Out:
# en    6842
# fr     355
# ja     274
# it     267
# es     198
# de     183
# ru     122
# cn      47
# da      38
# sv      37
# hi      35
# cs      34
# zh      30
# ko      26
# pt      24
# tr      23
# el      17
# nl      14
# pl      11
# hu       8
# th       7
# ta       7
# sr       7
# fi       6
# tl       6
# ab       6
# ar       5
# he       5
# ml       4
# no       3
# sh       2
# id       2
# nb       2
# ka       2
# mr       1
# bn       1
# sl       1
# te       1
# sk       1
# wo       1
# ms       1
# bs       1
# ca       1
# ur       1
# is       1
# vi       1
# eo       1
# Name: original_language, dtype: int64

# %%
def name_genre(genre_ids):
    names = []
    for genre_id in genre_ids:
        if genre_id not in genres:
            return
        else:
            names.append(genres[genre_id])
    return names

# %%
name_genre([27, 28])
# Out:
# [u'Horror', u'Action']

# %%
movies["genre_names"] = movies.apply(lambda x: name_genre(x["genre_ids"]),axis=1)

# %%
def includes_genre(target_genre, genre_names):
    if target_genre in genre_names:
        return 1
    else:
        return 0

# %%
movies["Science Fiction"] = movies.apply(lambda x: includes_genre("Science Fiction", x["genre_names"]),axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-f21bd34387be> in <module>()
# ----> 1 movies["Science Fiction"] = movies.apply(lambda x: includes_genre("Science Fiction", x["genre_names"]),axis=1)
#
# /Users/brianho/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4059                     if reduce is None:
#    4060                         reduce = True
# -> 4061                     return self._apply_standard(f, axis, reduce=reduce)
#    4062             else:
#    4063                 return self._apply_broadcast(f, axis)
#
# /Users/brianho/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4155             try:
#    4156                 for i, v in enumerate(series_gen):
# -> 4157                     results[i] = func(v)
#    4158                     keys.append(v.name)
#    4159             except Exception as e:
#
# <ipython-input-151-f21bd34387be> in <lambda>(x)
# ----> 1 movies["Science Fiction"] = movies.apply(lambda x: includes_genre("Science Fiction", x["genre_names"]),axis=1)
#
# <ipython-input-149-bb9fb9daca16> in includes_genre(target_genre, genre_names)
#       1 def includes_genre(target_genre, genre_names):
# ----> 2     if target_genre in genre_names:
#       3         return 1
#       4     else:
#       5         return 0
#
# TypeError: ("argument of type 'NoneType' is not iterable", u'occurred at index 1')

# %%
genres
# Out:
# {12: u'Adventure',
#  14: u'Fantasy',
#  16: u'Animation',
#  18: u'Drama',
#  27: u'Horror',
#  28: u'Action',
#  35: u'Comedy',
#  36: u'History',
#  37: u'Western',
#  53: u'Thriller',
#  80: u'Crime',
#  99: u'Documentary',
#  878: u'Science Fiction',
#  9648: u'Mystery',
#  10402: u'Music',
#  10749: u'Romance',
#  10751: u'Family',
#  10752: u'War',
#  10770: u'TV Movie'}
