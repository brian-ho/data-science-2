# %% [markdown]
# ### Milestone 2: Assembling training data, due Wednesday, April 12, 2017
#
# We are aware that you have little time this week, due to the midterm. So this milestone is a bit easier to achieve than the others. The goal for this week is to prepare the data for the modeling phase of the project. You should end up with a typical data setup of training data X and data labels Y.
#
# The exact form of X and Y depends on the ideas you had previously. In general though Y should involve the genre of a movie, and X the features you want to include to predict the genre. Remember from the lecture that more features does not necessarily equal better prediction performance. Use your application knowledge and the insight you gathered from your genre pair analysis and additional EDA to design Y. Do you want to include all genres? Are there genres that you assume to be easier to separate than others? Are there genres that could be grouped together? There is no one right answer here. We are looking for your insight, so be sure to describe your decision process in your notebook.
#
# In preparation for the deep learning part we strongly encourage you to have two sets of training data X, one with the metadata and one with the movie posters. Make sure to have a common key, like the movie ID, to be able to link the two sets together. Also be mindful of the data rate when you obtain the posters. Time your requests and choose which poster resolution you need. In most cases w500 should be sufficient, and probably a lower resolution will be fine.
#
# The notebook to submit this week should at least include:
#
# - Discussion about the imbalanced nature of the data and how you want to address it
# - Description of your data
# - What does your choice of Y look like?
# - Which features do you choose for X and why?
# - How do you sample your data, how many samples, and why?
#
# *Important*: You do not need to upload the data itself to Canvas.

# %%
### Let's import some libraries!
import imdb
# import httplib
import json
import requests
import pandas as pd
import numpy as np
import time
import wget
import matplotlib
# import random
# from sklearn import cluster
# from sklearn import metrics
# from IPython.display import IFrame
# from sklearn.decomposition import PCA
# %matplotlib inline

# %%
## Get the genre codes from IMDB
payload = {'api_key': '9290a6fe9125b32e7bbe5512036be0d0'}
r = requests.get('https://api.themoviedb.org/3/genre/movie/list', params=payload)

genres = pd.DataFrame.from_dict(r.json()["genres"])
genres = genres.set_index("id")
print genres
# Out:
#                   name
# id
# 28              Action
# 12           Adventure
# 16           Animation
# 35              Comedy
# 80               Crime
# 99         Documentary
# 18               Drama
# 10751           Family
# 14             Fantasy
# 36             History
# 27              Horror
# 10402            Music
# 9648           Mystery
# 10749          Romance
# 878    Science Fiction
# 10770         TV Movie
# 53            Thriller
# 10752              War
# 37             Western

# %%
### Queries to TMDB
    
# intial API parameters
payload = {'api_key': '9290a6fe9125b32e7bbe5512036be0d0',
           'sort_by':'popularity.desc',
           'primary_release_year': 2010,
           'page': 1,
           'with_genres':878}

r = requests.get('https://api.themoviedb.org/3/discover/movie?', params=payload)

test_movies = r.json()
# print 'For ', year, ' there are ', r.json()['total_results'], ' total results across ', r.json()['total_pages'], ' total pages.'

# tmdb_movies = pd.concat([tmdb_movies, pd.io.json.json_normalize(r.json()['results'])])

'''    
    for page in range(1, 51):
            start = time.time()
            payload = {'api_key': '9290a6fe9125b32e7bbe5512036be0d0',
                       'sort_by':'popularity.desc',
                       'primary_release_date.gte':year,
                       'primary_release_date.lte':year+1,
                       'page': page}
            
            r = requests.get('https://api.themoviedb.org/3/discover/movie?', params=payload)
            
            if page == 1:
                print 'For ', year, ' there are ', r.json()['total_results'], ' total results across ', r.json()['total_pages'], ' total pages.'
                
                if year == 2006:
                    tmdb_movies = pd.io.json.json_normalize(r.json()['results'])
            
            else:
                tmdb_movies = pd.concat([tmdb_movies, pd.io.json.json_normalize(r.json()['results'])])
            
            delay = time.time()-start
            
            if delay < 0.25:
                time.sleep(0.25-delay)

tmdb_movies.head()
'''
# Out:
# "    \n    for page in range(1, 51):\n            start = time.time()\n            payload = {'api_key': '9290a6fe9125b32e7bbe5512036be0d0',\n                       'sort_by':'popularity.desc',\n                       'primary_release_date.gte':year,\n                       'primary_release_date.lte':year+1,\n                       'page': page}\n            \n            r = requests.get('https://api.themoviedb.org/3/discover/movie?', params=payload)\n            \n            if page == 1:\n                print 'For ', year, ' there are ', r.json()['total_results'], ' total results across ', r.json()['total_pages'], ' total pages.'\n                \n                if year == 2006:\n                    tmdb_movies = pd.io.json.json_normalize(r.json()['results'])\n            \n            else:\n                tmdb_movies = pd.concat([tmdb_movies, pd.io.json.json_normalize(r.json()['results'])])\n            \n            delay = time.time()-start\n            \n            if delay < 0.25:\n                time.sleep(0.25-delay)\n\ntmdb_movies.head()\n"

# %%
type(test_movies["results"])
# Out:
# list

# %%
r.json()
# Out:
# {u'page': 1,
#  u'results': [{u'adult': False,
#    u'backdrop_path': u'/s2bT29y0ngXxxu2IA8AOzzXTRhd.jpg',
#    u'genre_ids': [28, 53, 878, 9648, 12],
#    u'id': 27205,
#    u'original_language': u'en',
#    u'original_title': u'Inception',
#    u'overview': u'Cobb, a skilled thief who commits corporate espionage by infiltrating the subconscious of his targets is offered a chance to regain his old life as payment for a task considered to be impossible: "inception", the implantation of another person\'s idea into a target\'s subconscious.',
#    u'popularity': 9.859907,
#    u'poster_path': u'/qmDpIHrmpJINaRKAfWQfftjCdyi.jpg',
#    u'release_date': u'2010-07-14',
#    u'title': u'Inception',
#    u'video': False,
#    u'vote_average': 8,
#    u'vote_count': 11142},
#   {u'adult': False,
#    u'backdrop_path': u'/jxdSxqAFrdioKgXwgTs5Qfbazjq.jpg',
#    u'genre_ids': [12, 28, 878],
#    u'id': 10138,
#    u'original_language': u'en',
#    u'original_title': u'Iron Man 2',
#    u'overview': u"With the world now aware of his dual life as the armored superhero Iron Man, billionaire inventor Tony Stark faces pressure from the government, the press and the public to share his technology with the military. Unwilling to let go of his invention, Stark, with Pepper Potts and James 'Rhodey' Rhodes at his side, must forge new alliances \u2013 and confront powerful enemies.",
#    u'popularity': 4.960944,
#    u'poster_path': u'/ArqpkNYGfcTIA6umWt6xihfIZZv.jpg',
#    u'release_date': u'2010-04-28',
#    u'title': u'Iron Man 2',
#    u'video': False,
#    u'vote_average': 6.6,
#    u'vote_count': 5601},
#   {u'adult': False,
#    u'backdrop_path': u'/sLn5HvFwLIL7Fof2Jj0JEeJSrGC.jpg',
#    u'genre_ids': [28, 878, 12, 53],
#    u'id': 34851,
#    u'original_language': u'en',
#    u'original_title': u'Predators',
#    u'overview': u"A mercenary reluctantly leads a motley crew of warriors who soon come to realize they've been captured and deposited on an alien planet by an unknown nemesis. With the exception of a peculiar physician, they are all cold-blooded killers, convicts, death squad members... hunters who have now become the hunted.",
#    u'popularity': 3.807622,
#    u'poster_path': u'/xtx2kOAySd2jUVU4eylCgkkIi5v.jpg',
#    u'release_date': u'2010-07-03',
#    u'title': u'Predators',
#    u'video': False,
#    u'vote_average': 5.9,
#    u'vote_count': 960},
#   {u'adult': False,
#    u'backdrop_path': u'/yT91We6RqDDfM4q7RX1QTHaq5q4.jpg',
#    u'genre_ids': [28, 53, 878],
#    u'id': 20504,
#    u'original_language': u'en',
#    u'original_title': u'The Book of Eli',
#    u'overview': u'A post-apocalyptic tale, in which a lone man fights his way across America in order to protect a sacred book that holds the secrets to saving humankind.',
#    u'popularity': 3.41068,
#    u'poster_path': u'/qL3FnEug9DyBcaBXVb0oT3DJMJu.jpg',
#    u'release_date': u'2010-01-14',
#    u'title': u'The Book of Eli',
#    u'video': False,
#    u'vote_average': 6.6,
#    u'vote_count': 1754},
#   {u'adult': False,
#    u'backdrop_path': u'/e1CMBwdeWytbSFSiEc9ax5ZSTzg.jpg',
#    u'genre_ids': [28, 53, 878],
#    u'id': 51620,
#    u'original_language': u'en',
#    u'original_title': u'Death Race 2',
#    u'overview': u"In the world's most dangerous prison, a new game is born: Death Race. The rules of this adrenaline-fueled blood sport are simple, drive or die. When repentant convict Carl Lucas discovers there's a price on his head, his only hope is to survive a twisted race against an army of hardened criminals and tricked-out cars.",
#    u'popularity': 3.366255,
#    u'poster_path': u'/5ARRXaWPgtIT9qKl8Db3MNuGvo3.jpg',
#    u'release_date': u'2010-11-12',
#    u'title': u'Death Race 2',
#    u'video': False,
#    u'vote_average': 5.4,
#    u'vote_count': 245},
#   {u'adult': False,
#    u'backdrop_path': u'/poNggE1pzQpezVcTUSPKpacujCP.jpg',
#    u'genre_ids': [12, 28, 878],
#    u'id': 20526,
#    u'original_language': u'en',
#    u'original_title': u'TRON: Legacy',
#    u'overview': u"Sam Flynn, the tech-savvy and daring son of Kevin Flynn, investigates his father's disappearance and is pulled into The Grid. With the help of a mysterious program named Quorra, Sam quests to stop evil dictator Clu from crossing into the real world.",
#    u'popularity': 3.30523,
#    u'poster_path': u'/vllvystwQjmXzy5OvBKnGl1JREF.jpg',
#    u'release_date': u'2010-12-10',
#    u'title': u'TRON: Legacy',
#    u'video': False,
#    u'vote_average': 6.3,
#    u'vote_count': 2363},
#   {u'adult': False,
#    u'backdrop_path': u'/o6anuGPog9853CPiaPQEMmdBVT0.jpg',
#    u'genre_ids': [16, 28, 35, 10751, 878],
#    u'id': 38055,
#    u'original_language': u'en',
#    u'original_title': u'Megamind',
#    u'overview': u'Bumbling supervillain Megamind finally defeats his nemesis, the superhero Metro Man. But without a hero, he loses all purpose and must find new meaning to his life.',
#    u'popularity': 2.827146,
#    u'poster_path': u'/amXAUSAUrnGuLGEyc1ZNhBvgbnF.jpg',
#    u'release_date': u'2010-10-28',
#    u'title': u'Megamind',
#    u'video': False,
#    u'vote_average': 6.7,
#    u'vote_count': 1468},
#   {u'adult': False,
#    u'backdrop_path': u'/91usy6D1cqS6xcj7t3gN6wfOBk3.jpg',
#    u'genre_ids': [18, 10749, 878],
#    u'id': 42188,
#    u'original_language': u'en',
#    u'original_title': u'Never Let Me Go',
#    u'overview': u'As children, Kathy, Ruth, and Tommy spend their childhood at an idyllic and secluded English boarding school. As they grow into adults, they must come to terms with the complexity and strength of their love for one another while also preparing for the haunting reality awaiting them.',
#    u'popularity': 2.575065,
#    u'poster_path': u'/i5sE6EINofvT7Xq0rpZz9jRbRMS.jpg',
#    u'release_date': u'2010-09-15',
#    u'title': u'Never Let Me Go',
#    u'video': False,
#    u'vote_average': 6.8,
#    u'vote_count': 563},
#   {u'adult': False,
#    u'backdrop_path': u'/86CKtVwpAT2aagWr7CWlWLzHNJ6.jpg',
#    u'genre_ids': [27, 53, 878],
#    u'id': 42307,
#    u'original_language': u'en',
#    u'original_title': u'Road Train',
#    u'overview': u'A supernatural thriller about a group of teenagers menaced by a driver-less train in the Australian outback.',
#    u'popularity': 2.482647,
#    u'poster_path': u'/nBzzmY5TBlfKrsYV5vUnjmd3fv1.jpg',
#    u'release_date': u'2010-05-28',
#    u'title': u'Road Train',
#    u'video': False,
#    u'vote_average': 3.6,
#    u'vote_count': 28},
#   {u'adult': False,
#    u'backdrop_path': u'/nfAeL5txnyRlxNwU9tIx9y9jxLP.jpg',
#    u'genre_ids': [18, 53, 878],
#    u'id': 43933,
#    u'original_language': u'en',
#    u'original_title': u'Monsters',
#    u'overview': u'Six years ago NASA discovered the possibility of alien life within our solar system. A probe was launched to collect samples, but crashed upon re-entry over Central America. Soon after, new life forms began to appear and half of Mexico was quarantined as an infected zone. Today, the American and Mexican military still struggle to contain "the creatures," while a journalist agrees to escort a shaken tourist through the infected zone in Mexico to the safety of the U.S. border.',
#    u'popularity': 2.45088,
#    u'poster_path': u'/lfwDoVtWElt1ecLv9NrQryOn6Rl.jpg',
#    u'release_date': u'2010-06-18',
#    u'title': u'Monsters',
#    u'video': False,
#    u'vote_average': 6.3,
#    u'vote_count': 483},
#   {u'adult': False,
#    u'backdrop_path': u'/i4xX5YUHUfNvlHt65DPDXQgJT7m.jpg',
#    u'genre_ids': [878, 35, 12],
#    u'id': 23048,
#    u'original_language': u'en',
#    u'original_title': u'Hot Tub Time Machine',
#    u'overview': u'A malfunctioning time machine at a ski resort takes a man back to 1986 with his two friends and nephew, where they must relive a fateful night and not change anything to make sure the nephew is born.',
#    u'popularity': 2.38349,
#    u'poster_path': u'/zERxFAXiQdPAfsumIIcBFH8fOVt.jpg',
#    u'release_date': u'2010-03-26',
#    u'title': u'Hot Tub Time Machine',
#    u'video': False,
#    u'vote_average': 6,
#    u'vote_count': 744},
#   {u'adult': False,
#    u'backdrop_path': u'/2LEtGEGV6I1UfheBI3yL4hvaGHc.jpg',
#    u'genre_ids': [27, 28, 878, 53],
#    u'id': 44037,
#    u'original_language': u'en',
#    u'original_title': u'Lake Placid 3',
#    u'overview': u"A game warden moves his family to Lake Placid, once the site of deadly crocodile attacks. Locals assure him the crocs are gone, but his mischievous young son finds a few baby crocs and begins feeding them. They quickly grow into very big adults and start attacking the game warden's family and nearby town.",
#    u'popularity': 2.141034,
#    u'poster_path': u'/gSzn441p0Q8pIK8g5IaJwBvbGKo.jpg',
#    u'release_date': u'2010-08-21',
#    u'title': u'Lake Placid 3',
#    u'video': False,
#    u'vote_average': 4,
#    u'vote_count': 27},
#   {u'adult': False,
#    u'backdrop_path': u'/ooDLzlnLWbhQvJnd1TOydRHFS9q.jpg',
#    u'genre_ids': [28, 35, 27, 9648, 878, 53],
#    u'id': 43935,
#    u'original_language': u'en',
#    u'original_title': u'Dylan Dog: Dead of Night',
#    u'overview': u'Supernatural private eye, Dylan Dog, seeks out the monsters of the Louisiana bayou in his signature red shirt, black jacket and blue jeans.',
#    u'popularity': 1.976033,
#    u'poster_path': u'/jFedqY0YQnKAbmFq4HUeKat1gYL.jpg',
#    u'release_date': u'2010-10-26',
#    u'title': u'Dylan Dog: Dead of Night',
#    u'video': False,
#    u'vote_average': 4.9,
#    u'vote_count': 101},
#   {u'adult': False,
#    u'backdrop_path': u'/q5LRhDbHCLGzbQoakyjozXhIsPx.jpg',
#    u'genre_ids': [28, 878, 53, 80],
#    u'id': 31867,
#    u'original_language': u'en',
#    u'original_title': u'Repo Men',
#    u'overview': u'In the future, medical technology has advanced to the point where people can buy artificial organs to extend their lives. But if they default on payments, an organization known as the Union sends agents to repossess the organs. Remy is one of the best agents in the business, but when he becomes the recipient of an artificial heart, he finds himself in the same dire straits as his many victims.',
#    u'popularity': 1.866911,
#    u'poster_path': u'/owCZCoKCutG7cf3Gu2ykrbfyRnl.jpg',
#    u'release_date': u'2010-03-18',
#    u'title': u'Repo Men',
#    u'video': False,
#    u'vote_average': 6.1,
#    u'vote_count': 515},
#   {u'adult': False,
#    u'backdrop_path': u'/3kHohw6LV3dv9txFPye78zsaTN2.jpg',
#    u'genre_ids': [10770, 12, 14, 878],
#    u'id': 50674,
#    u'original_language': u'fr',
#    u'original_title': u'The Lost Future',
#    u'overview': u'A group of post-apocalyptic survivors, struggle to survive in a world where jungles and forests and primeval wetlands and deserts have obliterated civilization. They staunchly face genetically mutating beasts and mysterious diseases in an attempt to re-establish the human race as masters of Earth.',
#    u'popularity': 1.816443,
#    u'poster_path': u'/ttW7Y1BlxXZ3BQBomI11I22xMTr.jpg',
#    u'release_date': u'2010-11-13',
#    u'title': u'The Lost Future',
#    u'video': False,
#    u'vote_average': 4.5,
#    u'vote_count': 55},
#   {u'adult': False,
#    u'backdrop_path': u'/mNla2FQU3n8uLIX7PPfD3r2geCZ.jpg',
#    u'genre_ids': [16, 14, 35, 878],
#    u'id': 278427,
#    u'original_language': u'en',
#    u'original_title': u"Family Guy Presents: It's a Trap!",
#    u'overview': u"In this spectacular and offensively uproarious final chapter, Luke Skywalker (Chris) and Princess Leia (Lois) must travel to Tatooine to free Han Solo (Peter) by infiltrating the wretched stronghold of Jabba the Hutt (Joe), the galaxy's most loathsome and dreadful gangster. Once reunited, the Rebels team up with a tribe of Ewoks to combat the Imperial forces on the forest moon of Endor. Meanwhile the Emperor (Carter Pewterschmidt) and Darth Vader (Stewie) conspire to turn Luke to the dark side, and young Skywalker is determined to rekindle the spirit of the Jedi within his father. The Galactic Civil War has never been more outrageous, as the Rebel forces gather to attack the seemingly defenseless and incomplete second Death Star in the battle that will determine the fate of the galaxy.",
#    u'popularity': 1.774122,
#    u'poster_path': u'/hi1V4pE2H6AqlFNmSOxqORsAPgU.jpg',
#    u'release_date': u'2010-10-22',
#    u'title': u"Family Guy Presents: It's a Trap!",
#    u'video': False,
#    u'vote_average': 6.8,
#    u'vote_count': 113},
#   {u'adult': False,
#    u'backdrop_path': u'/nnCu3lQI9NW5kMI2HaQbIA9sVaw.jpg',
#    u'genre_ids': [27, 878],
#    u'id': 95547,
#    u'original_language': u'en',
#    u'original_title': u'Triassic Attack',
#    u'overview': u'A Native American owner of a kitschy roadside museum accidentally brings to life three dinosaur fossils. Now really annoyed, the giant dinos wreak havoc on the small town and the local university.',
#    u'popularity': 1.72338,
#    u'poster_path': u'/gmJuBFAc7bbRamtdQq31nYAWscR.jpg',
#    u'release_date': u'2010-11-27',
#    u'title': u'Triassic Attack',
#    u'video': False,
#    u'vote_average': 3.5,
#    u'vote_count': 13},
#   {u'adult': False,
#    u'backdrop_path': u'/2kGP9gJEONx1hjgRjbusXzAbKQf.jpg',
#    u'genre_ids': [16, 28, 53, 878],
#    u'id': 64956,
#    u'original_language': u'en',
#    u'original_title': u'Inception: The Cobol Job',
#    u'overview': u"The Cobol Job is a fourteen-minute animated prequel to Christopher Nolan\u2019s award-winning movie: Inception, detailing the heist on Mr. Kaneda's mind by Nash, Cobb, Arthur, and several Cobol Engineering thugs.",
#    u'popularity': 1.661603,
#    u'poster_path': u'/yr6XX4c7BOvxVjV6cJePwZdUlLn.jpg',
#    u'release_date': u'2010-12-07',
#    u'title': u'Inception: The Cobol Job',
#    u'video': False,
#    u'vote_average': 7.4,
#    u'vote_count': 182},
#   {u'adult': False,
#    u'backdrop_path': u'/7DDQp1l72rXjYZRwEgHg2TkbPcH.jpg',
#    u'genre_ids': [878],
#    u'id': 42684,
#    u'original_language': u'en',
#    u'original_title': u'Skyline',
#    u'overview': u'When strange lights descend on the city of Los Angeles, people are drawn outside like moths to a flame where an extraterrestrial force threatens to swallow the entire human population off the face of the Earth. Now the band of survivors must fight for their lives as the world unravels around them.',
#    u'popularity': 1.648332,
#    u'poster_path': u'/AdadT2HuwHkYWxbzme4QP77M6Wt.jpg',
#    u'release_date': u'2010-11-11',
#    u'title': u'Skyline',
#    u'video': False,
#    u'vote_average': 4.7,
#    u'vote_count': 403},
#   {u'adult': False,
#    u'backdrop_path': u'/bGDbLqSTQ0pg7fBeUgc8aht3q8D.jpg',
#    u'genre_ids': [28, 27, 878],
#    u'id': 52454,
#    u'original_language': u'en',
#    u'original_title': u'Mega Shark vs. Crocosaurus',
#    u'overview': u"When the prehistoric warm-water beast the Crocosaurus crosses paths with that cold-water monster the Mega Shark, all hell breaks loose in the oceans as the world's top scientists explore every option to halt the aquatic frenzy. Swallowing everything in their paths -- including a submarine or two -- Croc and Mega lead an explorer and an oceanographer on a wild chase. Eventually, the desperate men turn to a volcano for aid.",
#    u'popularity': 1.635601,
#    u'poster_path': u'/j71V5e92YTP0rFGOX3kY8nHxujL.jpg',
#    u'release_date': u'2010-12-21',
#    u'title': u'Mega Shark vs. Crocosaurus',
#    u'video': False,
#    u'vote_average': 2.6,
#    u'vote_count': 32}],
#  u'total_pages': 13,
#  u'total_results': 253}

# %%
json.load(str(r.text))
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-104-73c66df38751> in <module>()
# ----> 1 json.load(str(r.text))
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\u2013' in position 1069: ordinal not in range(128)

# %%
pd.read_json(str(r.json()["results"]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-08c78a362a55> in <module>()
# ----> 1 pd.read_json(str(r.json()["results"]))
#
# /Users/brianho/anaconda2/lib/python2.7/site-packages/pandas/io/json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     209         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     210                           keep_default_dates, numpy, precise_float,
# --> 211                           date_unit).parse()
#     212
#     213     if typ == 'series' or obj is None:
#
# /Users/brianho/anaconda2/lib/python2.7/site-packages/pandas/io/json.pyc in parse(self)
#     277
#     278         else:
# --> 279             self._parse_no_numpy()
#     280
#     281         if self.obj is None:
#
# /Users/brianho/anaconda2/lib/python2.7/site-packages/pandas/io/json.pyc in _parse_no_numpy(self)
#     494         if orient == "columns":
#     495             self.obj = DataFrame(
# --> 496                 loads(json, precise_float=self.precise_float), dtype=None)
#     497         elif orient == "split":
#     498             decoded = dict((str(k), v)
#
# ValueError: Expected object or value
